# %% [markdown]
# ### Query1

# %%
str = "Innomatics "
print(str)
# Out:
# Innomatics

# %%
print(str * 3)
# Out:
# Innomatics Innomatics Innomatics

# %% [markdown]
# ### Query2

# %% [markdown]
# ![image.png](attachment:c30c8d15-3de1-4539-b462-9f63dfcc4c28.png)!

# %%
s = "MedidaSampurna"
print( s[-1], s[-3], s[3], s[2:7], s[2:7:1], s[2:7:2], s[2:7:-1], s[2:7:-2], s[7:2:1], s[7:2:-1], s[7:2:-2], sep = '\n')
# Out:
# a
# r
# i
# didaS
# didaS
# ddS
#
#
#
# aSadi
# aai

# %%
# My Examples
R = "InnomaticsResearchLab"
print(R[::1], R[::-1], R[6::2], R[-12::-1], R[:6], R[::], R[1:1:1], R[::-20], R[:-5:], sep = '\n')
# Out:
# InnomaticsResearchLab
# baLhcraeseRscitamonnI
# tcRsacLb
# scitamonnI
# Innoma
# InnomaticsResearchLab
#
# bI
# InnomaticsResear

# %% [markdown]
# ### Query3

# %%
# string.find() and string.index() both methods will return the lowest index of the substring but the difference is:
# In case of no substring existed in the string find() will return -1 whereas index() will raise an value error
print(R.find("m"))# this is to check the substring
print(R.index("m"))# this is to check the index of the substring
R.find("u")
# Out:
# 4
# 4
# -1

# %%
R.index("u")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 R.index("u")
#
# ValueError: substring not found

# %% [markdown]
# ### Query4

# %%
S = "Ram Raj Ram"
print(S.capitalize())
# Out:
# Ram raj ram

# %% [markdown]
# ### Query5

# %%
first_name = "Medida"
last_name = "Sampurna"
print((first_name +" " +last_name).title())
# Out:
# Medida Sampurna

# %% [markdown]
# ### Query6

# %%
is_palindrome = False
s = "madam"
sRev = s[::-1]
if(s == sRev):
    is_palindrome = True
print(is_palindrome)
# Out:
# True

# %% [markdown]
# ### Query7

# %%
S = "InnomaticsResearchLabs"
print("-".join(S[::2]))
# Out:
# I-n-m-t-c-R-s-a-c-L-b
